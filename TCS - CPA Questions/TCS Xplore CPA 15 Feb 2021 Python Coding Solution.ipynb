# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
class Traveler:
    def __init__(self,traveler_name, traveled_country, traveler_age, country_from):
        self.traveler_name = traveler_name
        self.traveled_country = traveled_country
        self.traveler_age = traveler_age
        self.country_from = country_from

class TravelAgency:
    def __init__(self,traveler_list):
        self.traveler_list = traveler_list
    
    def count_travelers_traveled_country(self, country):
        count = 0 
        for i in self.traveler_list:
            for j in i.traveled_country:
                if j == country:
                    count += 1
        
        return count
    
    def get_traveler_travelled_max_country(self):
        traveler = ""
        max = 0
        for i in traveler_list:
            length = len(i.traveled_country)
            if (length > max):
                max = len(i.traveled_country)
                traveler = i.traveler_name
                
        return traveler
    
    
n = int(input())
traveler_list = []

for i in range(n):
    traveler_name = input()
    n_countries = int(input())
    countries = []
    for j in range(n_countries):
        country = input()
        countries.append(country)
        
    traveler_age = int(input())
    country_from = input()
    
    traveler_list.append(Traveler(traveler_name, countries, traveler_age, country_from))
    
    
object1 = TravelAgency(traveler_list)

name_of_country = input()

print(object1.count_travelers_traveled_country(name_of_country))
print(object1.get_traveler_travelled_max_country())
# Out:
# 5
# sachin
# 4
# japan
# brazil
# china
# nepal
# 40
# india
# kamini
# 4
# denmark
# australia
# indonesia
# ghana
# 37
# nepal
# saurav
# 6
# brazil
# bhutan
# afganistan
# uk
# nepal
# newzeland
# 32
# bangladesh
# ricky
# 3
# australia
# europe
# germany
# 42
# uk
# dravid
# 2
# india
# bhutan
# 39
# pakistan
# australia
# 2
# saurav

# %% [markdown]
# ![Screenshot%202021-06-13%20185415.png](attachment:Screenshot%202021-06-13%20185415.png)
