# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
class Product:
    def __init__(self,productName, productType, unitPrice, qtyOnHand ):
        self.productName = productName.lower() 
        self.productType = productType.lower()
        self.unitPrice   = unitPrice 
        self.qtyOnHand   = qtyOnHand 
        
        
        
class Store:
    def __init__(self, product_list):
        self.product_list = product_list
        
    def purchase_product(self,productName,qtyOnHand):
        
        for i in self.product_list:
            
            if i.productName == productName.lower() and i.qtyOnHand==0:
                return None
           
            elif i.productName == productName.lower() and i.qtyOnHand < qtyOnHand:
                bill = i.unitPrice*i.qtyOnHand
                product.qtyOnHand=0
                return bill
            
            elif i.productName == productName.lower() and i.qtyOnHand >= qtyOnHand:
                bill = i.unitPrice*qtyOnHand
                i.qtyOnHand = i.qtyOnHand-qtyOnHand
                return bill
                
            return None
        


if __name__=="__main__":
    
    n = int(input())
    products = []

    for i in range(n):
        productName = input()
        productType = input()
        unitPrice = int(input())
        qtyOnHand = int(input())
    
        product = Product(productName, productType, unitPrice, qtyOnHand)
        products.append(product)
    

    obj = Store(products)

    product_name = input()
    quantity = int(input())

    bill = obj.purchase_product(product_name, quantity)

    if bill==None:
        print("Product Not Available")
        for i in obj.product_list:
            print(i.productName," ",i.qtyOnHand)
        
    else:
        print(bill)
        for i in obj.product_list:
            print(i.productName," ",i.qtyOnHand)
# Out:
# 3
# White board
# Stationary
# 200
# 4
# Duster
# Stationary
# 20
# 10
# Marker
# Stationary
# 40
# 0
# Marker
# 5
# Product Not Available
# white board   4
# duster   10
# marker   0

# %% [markdown]
# ![image.png](attachment:image.png)
