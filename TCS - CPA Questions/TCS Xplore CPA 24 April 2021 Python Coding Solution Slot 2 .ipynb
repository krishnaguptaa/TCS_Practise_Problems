# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
class Employee:
    def __init__(self, eId, eName, Dept, salary, role):
        self.eId = eId
        self.eName = eName
        self.Dept = Dept
        self.salary = salary
        self.role = role
        
    def calaculateIncentive(self, perDict):
        for i in perDict.keys():
            if self.role.lower() == i.lower():
                incentive = self.salary*(perDict[i])/100
                
        return incentive
                
                
                
                
def calculateEmployeeSalaryByRole(role, employee_list, perDict):
    flag = 0
    lists = []
    for employee in employee_list:
        if employee.role.lower()==role.lower():
            incentive = employee.calaculateIncentive(perDict)
            employee.salary += incentive
            lists.append(employee)
            
    return lists
                

    
n = int(input())
objList = []
Incentive_Dict = {}
for i in range(n):
    role = input()
    incentive = int(input())
    Incentive_Dict[role] = incentive
    
    
m = int(input())    
for i in range(m):
    eId = int(input())
    eName = input()
    Dept = input()
    salary = int(input())
    role = input()
    objList.append(Employee(eId, eName, Dept, salary, role))
    
role = input()

# print incentive for first employee
val = objList[0].calaculateIncentive(Incentive_Dict)
print(val)

# salaries after incentives
salary_list = calculateEmployeeSalaryByRole(role, objList, edict)
for i in salary_list:
    print(i.eId, i.eName, i.salary)
# Out:
# 3
# Manager
# 20
# team member
# 15
# junior grade
# 10
# 4
# 101
# Ashok
# TD
# 20000
# Manager
# 102
# Rajesh
# RR
# 30000
# Manager
# 103
# Mukesh
# TD
# 10000
# Junior grade
# 104
# Radhika
# HR
# 5000
# Team Member
# Manager
# 4000.0
# 101 Ashok 24000.0
# 102 Rajesh 36000.0

# %% [markdown]
# ![image.png](attachment:image.png)
